# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import io
import base64

def plot_boxplot_numeric_variables(df, output_file):
    # Select only the numeric columns
    numeric_cols = df.select_dtypes(include=[np.number]).columns

    # Create a file to save the plots
    with open(output_file, 'w') as html_output:
        html_output.write("<html><body>\n")

        for col in numeric_cols:
            plt.figure(figsize=(6, 4))  # Smaller figure size
            
            # Box plot
            sns.boxplot(x=df[col])
            plt.title(f'Box Plot: {col}')
            plt.xlabel(col)

            # Save the plot to a bytes buffer
            buffer = io.BytesIO()
            plt.savefig(buffer, format='png', bbox_inches='tight')
            plt.close()

            # Convert the bytes buffer to base64 encoded string
            buffer.seek(0)
            plot_base64 = base64.b64encode(buffer.getvalue()).decode()

            # Write the plot to the HTML file
            html_output.write(f"<h2>{col}</h2>\n")
            html_output.write(f"<img src='data:image/png;base64,{plot_base64}' alt='{col} Box Plot'>\n")

        html_output.write("</body></html>")

# Example usage
# Assuming you have a DataFrame named 'df' containing your data
output_file = 'output_boxplots.html'
plot_boxplot_numeric_variables(df, output_file)
